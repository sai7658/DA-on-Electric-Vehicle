# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/dataset.csv')
df.head()
# Out:
#    VIN (1-10)     County      City State  Postal Code  Model Year       Make  \
# 0  JTMEB3FV6N     Monroe  Key West    FL        33040        2022     TOYOTA
# 1  1G1RD6E45D      Clark  Laughlin    NV        89029        2013  CHEVROLET
# 2  JN1AZ0CP8B     Yakima    Yakima    WA        98901        2011     NISSAN
# 3  1G1FW6S08H     Skagit  Concrete    WA        98237        2017  CHEVROLET
# 4  3FA6P0SU1K  Snohomish   Everett    WA        98201        2019       FORD
#
#         Model                   Electric Vehicle Type  \
# 0  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     BOLT EV          Battery Electric Vehicle (BEV)
# 4      FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible              42
# ...

# %%
df.shape
# Out:
# (112634, 17)

# %%
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  112634.000000  112634.000000   112634.000000  112634.000000
# mean    98156.226850    2019.003365       87.812987    1793.439681
# std      2648.733064       2.892364      102.334216   10783.753486
# min      1730.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2017.000000        0.000000       0.000000
# 50%     98119.000000    2020.000000       32.000000       0.000000
# 75%     98370.000000    2022.000000      208.000000       0.000000
# max     99701.000000    2023.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         112348.000000    1.126340e+05       1.126340e+05
# mean              29.805604    1.994567e+08       5.296650e+10
# std               14.700545    9.398427e+07       1.699104e+09
# min                1.000000    4.777000e+03       1.101001e+09
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112634 entries, 0 to 112633
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         112634 non-null  object
#  1   County                                             112634 non-null  object
#  2   City                                               112634 non-null  object
#  3   State                                              112634 non-null  object
#  4   Postal Code                                        112634 non-null  int64
#  5   Model Year                                         112634 non-null  int64
#  6   Make                                               112634 non-null  object
#  7   Model                                              112614 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 0
# City                                                   0
# State                                                  0
# Postal Code                                            0
# Model Year                                             0
# Make                                                   0
# Model                                                 20
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 286
# DOL Vehicle ID                                         0
# Vehicle Location                                      24
# Electric Utility                                     443
# ...

# %%
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  112634.000000  112634.000000   112634.000000  112634.000000
# mean    98156.226850    2019.003365       87.812987    1793.439681
# std      2648.733064       2.892364      102.334216   10783.753486
# min      1730.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2017.000000        0.000000       0.000000
# 50%     98119.000000    2020.000000       32.000000       0.000000
# 75%     98370.000000    2022.000000      208.000000       0.000000
# max     99701.000000    2023.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         112348.000000    1.126340e+05       1.126340e+05
# mean              29.805604    1.994567e+08       5.296650e+10
# std               14.700545    9.398427e+07       1.699104e+09
# min                1.000000    4.777000e+03       1.101001e+09
# ...

# %%
df.dropna(inplace=True)

# %%
# There is only one% null values i tought removing null values is a good approach
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %% [markdown]
# ### **Univarite Analysis**

# %%
co = df['Make'].value_counts()
sns.barplot(x=co.index,y=co.values)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Majority of the market occupied by tesla

# %%
co = df['County'].value_counts()
sns.barplot(x=co.index,y=co.values)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 60-70% market occupied by king country

# %%
sns.histplot(df['Electric Range'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.histplot(df['Model Year'])
# Out:
# <Axes: xlabel='Model Year', ylabel='Count'>

# %%
sns.histplot(df['Base MSRP'])
plt.title('Distribution of Base MSRP')
plt.show()

# %%
co = df['Legislative District'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=co.index, y=co.values)
plt.title('Count of Legislative Districts')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## **Bivariate Analysis**

# %%
sns.scatterplot(x='Electric Range', y='Base MSRP', data=df)
# Out:
# <Axes: xlabel='Electric Range', ylabel='Base MSRP'>

# %%
sns.boxplot(x='Model Year', y='Base MSRP', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.lineplot(x='Model Year', y='Electric Range', data=df)
# Out:
# <Axes: xlabel='Model Year', ylabel='Electric Range'>

# %%
correlation_matrix = df[['Electric Range', 'Base MSRP', 'Model Year']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# * Electric range and Base Msrp has positive correlation

# %%
# !pip install plotly

# %%
import plotly.express as px

# %%
co = df['County'].value_counts()
px.bar(df, x=co.index, y=co.values)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ev_count = df.groupby('State').size()
ev_count
# Out:
# State
# WA    112152
# dtype: int64

# %%
df['State'].value_counts()
# Out:
# State
# WA    112152
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    VIN (1-10)     County      City State  Postal Code  Model Year       Make  \
# 0  JN1AZ0CP8B     Yakima    Yakima    WA        98901        2011     NISSAN
# 1  1G1FW6S08H     Skagit  Concrete    WA        98237        2017  CHEVROLET
# 2  3FA6P0SU1K  Snohomish   Everett    WA        98201        2019       FORD
# 3  5YJ3E1EB5J  Snohomish   Bothell    WA        98021        2018      TESLA
# 4  1N4AZ0CP4D  Snohomish   Everett    WA        98203        2013     NISSAN
#
#      Model                   Electric Vehicle Type  \
# 0     LEAF          Battery Electric Vehicle (BEV)
# 1  BOLT EV          Battery Electric Vehicle (BEV)
# 2   FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 3  MODEL 3          Battery Electric Vehicle (BEV)
# 4     LEAF          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible              73
# ...

# %%
ev_count_by_county = df.groupby('State').size().reset_index(name='ev_count')
ev_count_by_county
# Out:
#    State  ev_count
# 0     AK         1
# 1     AL         1
# 2     AR         4
# 3     AZ         6
# 4     CA        76
# 5     CO         9
# 6     CT         6
# 7     DC         6
# 8     DE         1
# 9     FL         6
# 10    GA         7
# 11    HI         4
# 12    ID         2
# 13    IL         6
# 14    KS         3
# 15    KY         1
# 16    LA         3
# 17    MA         3
# 18    MD        26
# 19    ME         1
# 20    MN         1
# 21    MO         3
# 22    MS         1
# 23    NC         7
# 24    ND         1
# 25    NE         5
# 26    NH         2
# 27    NJ         3
# 28    NM         1
# 29    NV         8
# 30    NY         4
# 31    OH         2
# 32    OK         1
# 33    OR         5
# 34    PA         3
# 35    RI         1
# 36    SC         5
# 37    SD         1
# 38    TN         3
# 39    TX        14
# 40    UT         4
# 41    VA        36
# 42    WA    112348
# 43    WI         1
# 44    WY         2

# %%
state_vehicle_count = df.groupby(['State']).size().reset_index(name='num_vehicles')
state_vehicle_count
# Out:
#    State  num_vehicles
# 0     AK             1
# 1     AL             1
# 2     AR             4
# 3     AZ             6
# 4     CA            76
# 5     CO             9
# 6     CT             6
# 7     DC             6
# 8     DE             1
# 9     FL             6
# 10    GA             7
# 11    HI             4
# 12    ID             2
# 13    IL             6
# 14    KS             3
# 15    KY             1
# 16    LA             3
# 17    MA             3
# 18    MD            26
# 19    ME             1
# 20    MN             1
# 21    MO             3
# 22    MS             1
# 23    NC             7
# 24    ND             1
# 25    NE             5
# 26    NH             2
# 27    NJ             3
# 28    NM             1
# 29    NV             8
# 30    NY             4
# 31    OH             2
# 32    OK             1
# 33    OR             5
# 34    PA             3
# 35    RI             1
# 36    SC             5
# 37    SD             1
# 38    TN             3
# ...

# %%
fig = px.choropleth(
    state_vehicle_count,
    locations="State",
    locationmode="USA-states",
    color="num_vehicles",
    scope='usa',
    color_continuous_scale="Viridis" )



fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
! pip install bar_chart_race
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 3.5 MB/s eta 0:00:00
# ...

# %%
import bar_chart_race as bcr
import warnings

# Assuming 'df' is your DataFrame and it has 'Model Year' and 'Make' columns

warnings.filterwarnings("ignore", category=UserWarning)

# Convert 'Model Year' to string type
df['Model Year'] = df['Model Year'].astype(str)

# Group the data by 'Model Year' and 'Make', then count the number of EVs for each make in each year
grouped_data = df.groupby(['Model Year', 'Make']).size().reset_index(name='Count')

# Pivot the data to have 'Model Year' as index, 'Make' as columns, and 'Count' as values
pivoted_data = grouped_data.pivot(index='Model Year', columns='Make', values='Count')

# Fill NaN values with 0
pivoted_data = pivoted_data.fillna(0)

bcr.bar_chart_race(
    df=pivoted_data,
    title='Electric Vehicles Make Count Over Time',
    n_bars=10,                    # Top 10 bars to display
    period_length=1000,            # Speed of the race (1000 ms = 1 second per frame)
    fixed_order=False,             # Let the order of bars change as they race
    fixed_max=False,               # Allow the bar lengths to change dynamically
    steps_per_period=30,           # Smoother transitions between frames
    interpolate_period=False,      # No interpolation between frames for cleaner transitions
    period_label={'x': .99, 'y': .25, 'ha': 'right', 'va': 'center'},  # Customize the period label
    bar_label_size=7,              # Label size for the bars
    tick_label_size=8,             # Size for the tick labels
    figsize=(6, 4),                # Size of the chart
    dpi=144,                       # DPI for higher resolution
)
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:889: FutureWarning:
#
# Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# <video width="992" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...
